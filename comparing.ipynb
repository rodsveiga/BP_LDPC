# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/home/rodsveiga/Dropbox/DOC/van_error_codes/models'

file_VANs = path + '/p_versus_overlap_N_250_M_1000_K_5_p_prior_0100_steps_1000_code_0'
file_BP = 'p_versus_overlap_BP_N_250_M_1000_p_prior_0100_messages_5_it_8.txt'

# %%
p = [ float(x.split()[0]) for x in open(file_VANs).readlines()]
pho_VAN = [ float(x.split()[1]) for x in open(file_VANs).readlines()]
pho_BP = [ float(x.split()[1]) for x in open(file_BP).readlines()]

# %%
plt.plot(p, pho_VAN, 'o-', label= 'VAN')
plt.plot(p, pho_BP, 'o-', label= 'BP')
plt.xlabel('$p$', fontsize= 20)
plt.ylabel('$\\rho$', fontsize= 20)
plt.legend(fontsize=12)
plt.title('$N=250$,  $M=1000$,  $K=5$,  $p_{\\xi} = 0.1$', fontsize= 15)
#plt.savefig('comparing.png')
plt.show()

# %% [markdown]
# # Another try with VANs - March 4, 2020

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/home/rodsveiga/Dropbox/DOC/van_error_codes/models/_N_250_M_1000_K_5_p_prior_0100_steps_1000_code_0'

file_VANs = path + '/p_versus_overlap_N_250_M_1000_K_5_p_prior_0100_steps_1000_code_0_sampling'
file_BP = 'p_versus_overlap_BP_N_250_M_1000_p_prior_0100_messages_5_it_8.txt'

# %%
p = [ float(x.split()[0]) for x in open(file_VANs).readlines()]
pho_VAN = [ float(x.split()[1]) for x in open(file_VANs).readlines()]
pho_BP = [ float(x.split()[1]) for x in open(file_BP).readlines()]

# %%
plt.plot(p, pho_VAN, 'o-', label= 'VAN')
plt.plot(p, pho_BP, 'o-', label= 'BP')
plt.xlabel('$p$', fontsize= 20)
plt.ylabel('$\\rho$', fontsize= 20)
plt.legend(fontsize=12)
plt.title('$N=250$,  $M=1000$,  $K=5$,  $p_{\\xi} = 0.1$', fontsize= 15)
plt.savefig('comparing_2.png')
plt.show()
